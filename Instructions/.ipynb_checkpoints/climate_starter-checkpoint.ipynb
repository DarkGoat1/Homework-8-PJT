# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)
meas_q
# Out:
# [(2364, 'USC00519397', '2016-08-23', 0.0, 81.0),
#  (2365, 'USC00519397', '2016-08-24', 0.08, 79.0),
#  (2366, 'USC00519397', '2016-08-25', 0.08, 80.0),
#  (2367, 'USC00519397', '2016-08-26', 0.0, 79.0),
#  (2368, 'USC00519397', '2016-08-27', 0.0, 77.0),
#  (2369, 'USC00519397', '2016-08-28', 0.01, 78.0),
#  (2370, 'USC00519397', '2016-08-29', 0.0, 78.0),
#  (2371, 'USC00519397', '2016-08-30', 0.0, 79.0),
#  (2372, 'USC00519397', '2016-08-31', 0.13, 80.0),
#  (2373, 'USC00519397', '2016-09-01', 0.0, 81.0),
#  (2374, 'USC00519397', '2016-09-02', 0.0, 80.0),
#  (2375, 'USC00519397', '2016-09-03', 0.0, 79.0),
#  (2376, 'USC00519397', '2016-09-04', 0.03, 75.0),
#  (2377, 'USC00519397', '2016-09-05', None, 79.0),
#  (2378, 'USC00519397', '2016-09-06', None, 76.0),
#  (2379, 'USC00519397', '2016-09-07', 0.05, 76.0),
#  (2380, 'USC00519397', '2016-09-08', 0.0, 80.0),
#  (2381, 'USC00519397', '2016-09-09', 0.03, 79.0),
#  (2382, 'USC00519397', '2016-09-10', 0.0, 78.0),
# ...

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results

enddate = str(max(session.query(Measurement.date)))
# yearago = dt.datetime.strptime(enddate, "%Y-%m-%d") - dt.timedelta(days=365)
# yearagof = yearago.strftime('%Y-%m-%d')
meas_q = session.query(Measurement.id,
                       Measurement.station,
                      Measurement.date,
                      Measurement.prcp,
                      Measurement.tobs).filter(Measurement.date >= '2016-08-23').all()

meas_q2 = session.query(Measurement.id,
                       Measurement.station,
                      Measurement.date,
                      Measurement.prcp,
                      Measurement.tobs).all()

df = pd.DataFrame(meas_q, columns=['id', 'station', 'date', 'prcp', 'tobs'])
df2 = pd.DataFrame(meas_q2, columns=['id', 'station', 'date', 'prcp', 'tobs'])

df.head()

dates = df['date']
prcp = df['prcp']

# Calculate the date 1 year ago from the last data point in the database

# Perform a query to retrieve the data and precipitation scores

# Save the query results as a Pandas DataFrame and set the index to the date column

# Sort the dataframe by date

# Use Pandas Plotting with Matplotlib to plot the data

plt.bar(dates, prcp, label='Precipitation', width=1.2)
plt.xlabel('Date')
plt.ylabel('Precipitation')
plt.legend()

plt.show()

# %% [markdown]
# ![precipitation](Images/precipitation.png)

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
df['prcp'].describe()
# Out:
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000
# Name: prcp, dtype: float64

# %% [markdown]
# ![describe](Images/describe.png)

# %%
# Design a query to show how many stations are available in this dataset?
stationcount = df2['station'].nunique()
stationcount
# Out:
# 9

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
stationcount = df2.groupby('station').count()
stationcount
# Out:
#                id  date  prcp  tobs
# station
# USC00511918  1979  1979  1932  1979
# USC00513117  2709  2709  2696  2709
# USC00514830  2202  2202  1937  2202
# USC00516128  2612  2612  2484  2612
# USC00517948  1372  1372   683  1372
# USC00518838   511   511   342   511
# USC00519281  2772  2772  2772  2772
# USC00519397  2724  2724  2685  2724
# USC00519523  2669  2669  2572  2669

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?

#im just going to assume TOBS is the temperature measurement since nothing else seems to be in the meas/station tables! sorry if
#that's wrong!

meantable = df2.groupby('station').mean()
maxtable = df2.groupby('station').max()
mintable = df2.groupby('station').min()

data1 = meantable['tobs']
combinetable = pd.DataFrame(data=data1)

combinetable['meantemp'] = meantable['tobs']
combinetable['maxtemp'] = maxtable['tobs']
combinetable['mintemp'] = mintable['tobs']
combinetable['stationcount'] = stationcount['id']

combinetable
# Out:
#                   tobs   meantemp  maxtemp  mintemp  stationcount
# station
# USC00511918  71.615968  71.615968     87.0     53.0          1979
# USC00513117  72.689184  72.689184     85.0     59.0          2709
# USC00514830  74.873297  74.873297     85.0     58.0          2202
# USC00516128  70.915008  70.915008     84.0     58.0          2612
# USC00517948  74.684402  74.684402     87.0     58.0          1372
# USC00518838  72.724070  72.724070     83.0     58.0           511
# USC00519281  71.663781  71.663781     85.0     54.0          2772
# USC00519397  74.553231  74.553231     87.0     56.0          2724
# USC00519523  74.543649  74.543649     85.0     56.0          2669

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
meas_q3 = session.query(Measurement.id,
                       Measurement.station,
                      Measurement.date,
                      Measurement.prcp,
                      Measurement.tobs).filter(Measurement.station == "USC00519281", Measurement.date >= '2016-08-23').all()

topstationdf = pd.DataFrame(meas_q3, columns=['id', 'station', 'date', 'prcp', 'tobs'])

stationtemp = topstationdf.groupby('tobs').count()

obsnum = stationtemp['id']
temp = stationtemp.index.values

plt.bar(temp, obsnum)
plt.ylabel('Frequency')
plt.xlabel('Temperature')
# Out:
# Text(0.5,0,'Temperature')

# %% [markdown]
# ![precipitation](Images/station-histogram.png)

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.

#i don't understand this question... what date range are we supposed to try this on?

workingtemps = calc_temps('2016-08-23', '2017-08-23')
workingtemps[0][0]
# Out:
# 58.0

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)

workingmin = workingtemps[0][0]
workingavg = workingtemps[0][1]
workingmax = workingtemps[0][2]

plottemps = []
plottemps.append(workingmin)
plottemps.append(workingmax)
workingmax = workingtemps[0][2]

plt.boxplot(plottemps, meanline=workingavg)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20868827898>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20865648128>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20868827828>],
#  'medians': [<matplotlib.lines.Line2D at 0x20865648eb8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2086561c198>],
#  'means': []}

# %%
# Calculate the rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
combinetable['prcp'] = meantable['prcp']

meas_q4 = session.query(Station.id,
                       Station.station,
                      Station.name,
                      Station.latitude,
                      Station.longitude,
                       Station.elevation).all()

station_df = pd.DataFrame(meas_q4, columns=['id', 'station', 'name', 'latitude', 'longitude', 'elevation'])


combinetable2 = combinetable.merge(station_df, how="left", on='station')
combinetable2.sort_values(by=['prcp'], ascending=False)
# Out:
#        station       tobs   meantemp  maxtemp  mintemp  stationcount  \
# 3  USC00516128  70.915008  70.915008     84.0     58.0          2612
# 6  USC00519281  71.663781  71.663781     85.0     54.0          2772
# 5  USC00518838  72.724070  72.724070     83.0     58.0           511
# 1  USC00513117  72.689184  72.689184     85.0     59.0          2709
# 2  USC00514830  74.873297  74.873297     85.0     58.0          2202
# 8  USC00519523  74.543649  74.543649     85.0     56.0          2669
# 4  USC00517948  74.684402  74.684402     87.0     58.0          1372
# 7  USC00519397  74.553231  74.553231     87.0     56.0          2724
# 0  USC00511918  71.615968  71.615968     87.0     53.0          1979
#
#        prcp  id                                    name  latitude  longitude  \
# 3  0.429988   9            MANOA LYON ARBO 785.2, HI US  21.33310 -157.80250
# 6  0.212352   7                     WAIHEE 837.5, HI US  21.45167 -157.84889
# ...

# %% [markdown]
# ## Optional Challenge Assignment

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")[0]
# Out:
# (62.0, 69.15384615384616, 77.0)

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

normals = []
dates = ("05-27", "05-28", "05-29", "05-30", "05-31", "06-01", "06-02")

for x in dates:
    normals.append(daily_normals(x)[0])
    
normals

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date
# Out:
# [(65.0, 74.49090909090908, 80.0),
#  (67.0, 74.27777777777777, 82.0),
#  (64.0, 74.19607843137256, 80.0),
#  (69.0, 74.33333333333333, 81.0),
#  (68.0, 74.4, 81.0),
#  (64.0, 74.6140350877193, 81.0),
#  (65.0, 74.4, 81.0)]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index
normals_df = pd.DataFrame(data=normals, columns=['min', 'avg', 'max'])
normals_df
# Out:
#     min        avg   max
# 0  65.0  74.490909  80.0
# 1  67.0  74.277778  82.0
# 2  64.0  74.196078  80.0
# 3  69.0  74.333333  81.0
# 4  68.0  74.400000  81.0
# 5  64.0  74.614035  81.0
# 6  65.0  74.400000  81.0

# %%
# Plot the daily normals as an area plot with `stacked=False`

normals_df.plot(kind='area', stacked=False, alpha=0.5, colormap='Spectral',
        title='Area Plot')
